# %% [markdown]
# <a href="https://colab.research.google.com/github/joshuareyesc/MetNumUN2023I/blob/main/Lab9/Group12_Taylor_ln_x_plus_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taylor series of ln(x+1)

# %% [markdown]
# Interact code in Sagemath for $ln(x+1)$
#
# ```python
# # Interact Taylor Series of $$f(x) = e^x$$
# # Explanatory example: Taylor Series – wiki.sagemath.org/interact https://wiki.sagemath.org/interact
# x   = SR.var('x')
# x0  = 0
# f   = ln(x+1)
# p   = plot(f, -5, 5, thickness=2,legend_label='f(x) = ln(x+1)')
# dot = point((x0, f(x=x0)), pointsize=80, rgbcolor=(1, 0, 0))
# plotTaylor = [plot(f.taylor(x, x0, order), -5,5, color='green', thickness=2, legend_label= "Taylor " + str(order) +": "+ str(f.taylor(x, x0, order))) for order in range(5)]
#
# images = [p+dot+plotTaylor[int(order/12)] for order in range(60)]
#
# image= animate(images, ymin=-5, ymax=5)
# image.show()
# image.save('ln_x+1.gif')
# ```

# %% [markdown]
# Animate code in Sagemath for $ln(x+1)$
# ```python
# # Animate  Taylor Series of $$f(x) = e^x$$
# # MCS 320: Introduction to Symbolic Computation - Jan Verschelde, Mathematics, U. Illinois at Chicago  –
# # http://homepages.math.uic.edu/~jan/mcs320/mcs320notes/lec27.html#
# x   = SR.var('x')
# x0  = 0
# f   = ln(x+1)
# p   = plot(f, -5, 5, thickness=2,legend_label='f(x) = ln(x+1)')
# dot = point((x0, f(x=x0)), pointsize=80, rgbcolor=(1, 0, 0))
# plotTaylor = [plot(f.taylor(x, x0, order), -5,5, color='green', thickness=2, legend_label= "Taylor " + str(order) +": "+ str(f.taylor(x, x0, order))) for order in range(5,9)]
#
# images = [p+dot+plotTaylor[int(order/12)] for order in range(48)]
#
# image = animate(images, ymin=-5, ymax=5)
# image.show()
# image.save('ln_x+1(2).gif')
# ```

# %% [markdown]
# ![ln_x+1.gif](data:image/gif;base64,...)

# %% [markdown]
# ![ln_x+1(2).gif](data:image/gif;base64,...)

# %% [markdown]
# #What is value of the partial Taylor series of $ln(x+1)$ up to the  $10$-th term of $ln(x+1)$ about $0$ (Maclaurin  series) for $x=0.5$

# %%
# ∑_{i=0}^n  x^i/i

import math
n = 10
x = 0.5
ln_x_plus_1 = 0

for i in range(n+1):
    if i==0:
      continue
    else:
      ln_x_plus_1 += ((-1)**(i-1))*(x**i/(i))
      print('ln_of_x+1 ≈ ∑_{i=1}^'+str(i),'-1^'+str(i-1)+'*(x^'+str(i)+'/'+str(i)+') =',ln_x_plus_1, )  
print('ln(x+1) = ',math.log(x+1))
# Out:
# ln_of_x+1 ≈ ∑_{i=1}^1 -1^0*(x^1/1) = 0.5
# ln_of_x+1 ≈ ∑_{i=1}^2 -1^1*(x^2/2) = 0.375
# ln_of_x+1 ≈ ∑_{i=1}^3 -1^2*(x^3/3) = 0.4166666666666667
# ln_of_x+1 ≈ ∑_{i=1}^4 -1^3*(x^4/4) = 0.4010416666666667
# ln_of_x+1 ≈ ∑_{i=1}^5 -1^4*(x^5/5) = 0.40729166666666666
# ln_of_x+1 ≈ ∑_{i=1}^6 -1^5*(x^6/6) = 0.4046875
# ln_of_x+1 ≈ ∑_{i=1}^7 -1^6*(x^7/7) = 0.40580357142857143
# ln_of_x+1 ≈ ∑_{i=1}^8 -1^7*(x^8/8) = 0.40531529017857143
# ln_of_x+1 ≈ ∑_{i=1}^9 -1^8*(x^9/9) = 0.4055323040674603
# ln_of_x+1 ≈ ∑_{i=1}^10 -1^9*(x^10/10) = 0.4054346478174603
# ln(x+1) =  0.4054651081081644

# %% [markdown]
# # What is the minimun $n$ for which the error between the Taylor series for $ln(x+1)$ about $0$ (Maclaurin  series) for $x$ and *math.exp(x)*, is in absolute value less than  $\epsilon$.

# %%
# Returns Min n, |∑_{i=1}^{n}  x^i/i! - math.exp(x)| < epsilon and ∑_{i=0}^{n} x^i/i!   
import math
x = 0.5
epsilon = 10**(-6)
ln_x_plus_1 = 0
print("n".rjust(10)," ","∑_{i=1}^n  [(-1)^(i-1)][(x^i/i)]".center(21)," ","|x^n/n|".center(20)," ","epsilon".center(20))
delta = 1
i = 1
while  epsilon <= abs(delta):
  delta = ((-1)**(i-1))*(x**i/(i))
  ln_x_plus_1 += delta
  if i < 100 or i > 99900:
    print(format(i, '10'),"  ", format(ln_x_plus_1, '.17f'),"  ",format( abs(delta), '.17f'),"  ",format(epsilon, '.17f')) 
  i = i+1
print("n = ",i-1)
print('x = ',x)
print('ln(x+1) ≈ ∑_{i=1}^'+str(i-1),'[(-1)^(i-1)][(x^i/i)] =',ln_x_plus_1)    
print('ln(x+1) = ',math.log(x+1))
# Out:
#          n   ∑_{i=1}^n  [(-1)^(i-1)][(x^i/i)]         |x^n/n|                epsilon
#          1    0.50000000000000000    0.50000000000000000    0.00000100000000000
#          2    0.37500000000000000    0.12500000000000000    0.00000100000000000
#          3    0.41666666666666669    0.04166666666666666    0.00000100000000000
#          4    0.40104166666666669    0.01562500000000000    0.00000100000000000
#          5    0.40729166666666666    0.00625000000000000    0.00000100000000000
#          6    0.40468749999999998    0.00260416666666667    0.00000100000000000
#          7    0.40580357142857143    0.00111607142857143    0.00000100000000000
#          8    0.40531529017857143    0.00048828125000000    0.00000100000000000
#          9    0.40553230406746033    0.00021701388888889    0.00000100000000000
#         10    0.40543464781746030    0.00009765625000000    0.00000100000000000
#         11    0.40547903702200577    0.00004438920454545    0.00000100000000000
#         12    0.40545869196992246    0.00002034505208333    0.00000100000000000
#         13    0.40546808199396089    0.00000939002403846    0.00000100000000000
#         14    0.40546372233994304    0.00000435965401786    0.00000100000000000
#         15    0.40546575684515140    0.00000203450520833    0.00000100000000000
#         16    0.40546480317083500    0.00000095367431641    0.00000100000000000
# n =  16
# x =  0.5
# ln(x+1) ≈ ∑_{i=1}^16 [(-1)^(i-1)][(x^i/i)] = 0.405464803170835
# ln(x+1) =  0.4054651081081644

# %%
# Returns Min n, |∑_{i=1}^{n}  x^i/i! - math.exp(x)| < epsilon and ∑_{i=0}^{n} x^i/i!   
import math

x = 0.3
epsilon = 10**(-6)
delta = 1
ln_x_plus_1 = 0
i = 1
print("n".rjust(10)," ","∑_{i=1}^n  [(-1)^(i-1)][(x^i/i)]".center(21)," ","|x^n/n|".center(20)," ","epsilon".center(20))
while epsilon <= abs(delta):
    delta = ((-1)**(i-1))*(x**i/(i))
    ln_x_plus_1 += delta
    if i < 100 or i > 99900:
        print(format(i, '10'),"  ", format(ln_x_plus_1, '.17f'),"  ",format( abs(delta), '.17f'),"  ",format(epsilon, '.17f')) 
    i = i+1
print("n = ",i-1)
print('x = ',x)
print('ln(x+1) ≈ ∑_{i=1}^'+str(i-1),'[(-1)^(i-1)][(x^i/i)] =',ln_x_plus_1)    
print('ln(x+1) = ',math.log(x+1))
# Out:
#          n   ∑_{i=1}^n  [(-1)^(i-1)][(x^i/i)]         |x^n/n|                epsilon
#          1    0.29999999999999999    0.29999999999999999    0.00000100000000000
#          2    0.25500000000000000    0.04500000000000000    0.00000100000000000
#          3    0.26400000000000001    0.00900000000000000    0.00000100000000000
#          4    0.26197500000000001    0.00202500000000000    0.00000100000000000
#          5    0.26246100000000000    0.00048600000000000    0.00000100000000000
#          6    0.26233950000000000    0.00012150000000000    0.00000100000000000
#          7    0.26237074285714285    0.00003124285714286    0.00000100000000000
#          8    0.26236254160714284    0.00000820125000000    0.00000100000000000
#          9    0.26236472860714283    0.00000218700000000    0.00000100000000000
#         10    0.26236413811714282    0.00000059049000000    0.00000100000000000
# n =  10
# x =  0.3
# ln(x+1) ≈ ∑_{i=1}^10 [(-1)^(i-1)][(x^i/i)] = 0.2623641381171428
# ln(x+1) =  0.26236426446749106

# %% [markdown]
# # What is the minimun $n$ for which the $n$-th term of the Taylor series for $ln(x+1)
# $ about $0$ (Maclaurin  series) for $x$, is in absolute value less than  $\epsilon$.

# %%
# Returns Min n, |x^{n}/n!| < epsilon and ∑_{i=0}^{n} x^i/i!
import math

x = 0.5
epsilon = 10**(-6)

ln_x_plus_1 = 0

delta = 1
i = 0
print("n".rjust(10)," ","∑_{i=1}^n  [(-1)^(i-1)][(x^i/i)]".center(21)," ","|x^n/n|".center(20)," ","epsilon".center(20))
while  epsilon <= abs(delta):
  if i==0:
    pass
  else:
    delta = ((-1)**(i-1))*(x**i/(i))
    ln_x_plus_1 += delta
    print(format(i, '10'),"  ", format(ln_x_plus_1, '.17f'),"  ",format(delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1

print("n = ",i-1)
print('x = ',x)
print('ln(x+1) ≈ ∑_{i=1}^'+str(i-1),'[(-1)^(i-1)][(x^i/i)] =',ln_x_plus_1)    
print("epsilon =","{:.0e}".format(epsilon))     
print('ln(x+1) = ',math.log(x+1))
# Out:
#          n   ∑_{i=1}^n  [(-1)^(i-1)][(x^i/i)]         |x^n/n|                epsilon
#          1    0.50000000000000000    0.50000000000000000    1e-06
#          2    0.37500000000000000    -0.12500000000000000    1e-06
#          3    0.41666666666666669    0.04166666666666666    1e-06
#          4    0.40104166666666669    -0.01562500000000000    1e-06
#          5    0.40729166666666666    0.00625000000000000    1e-06
#          6    0.40468749999999998    -0.00260416666666667    1e-06
#          7    0.40580357142857143    0.00111607142857143    1e-06
#          8    0.40531529017857143    -0.00048828125000000    1e-06
#          9    0.40553230406746033    0.00021701388888889    1e-06
#         10    0.40543464781746030    -0.00009765625000000    1e-06
#         11    0.40547903702200577    0.00004438920454545    1e-06
#         12    0.40545869196992246    -0.00002034505208333    1e-06
#         13    0.40546808199396089    0.00000939002403846    1e-06
#         14    0.40546372233994304    -0.00000435965401786    1e-06
#         15    0.40546575684515140    0.00000203450520833    1e-06
#         16    0.40546480317083500    -0.00000095367431641    1e-06
# n =  16
# x =  0.5
# ln(x+1) ≈ ∑_{i=1}^16 [(-1)^(i-1)][(x^i/i)] = 0.405464803170835
# epsilon = 1e-06
# ln(x+1) =  0.4054651081081644

# %%
# Returns Min n, |x^{n}/n!| < epsilon and ∑_{i=0}^{n} x^i/i!
import math

x = 0.3
epsilon = 10**(-6)

ln_x_plus_1 = 0

delta = 1
i = 0
print("n".rjust(10)," ","∑_{i=1}^n  [(-1)^(i-1)][(x^i/i)]".center(21)," ","|x^n/n|".center(20)," ","epsilon".center(20))
while  epsilon <= abs(delta):
  if i==0:
    pass
  else:
    delta = ((-1)**(i-1))*(x**i/(i))
    ln_x_plus_1 += delta
    print(format(i, '10'),"  ", format(ln_x_plus_1, '.17f'),"  ",format(delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1

print("n = ",i-1)
print('x = ',x)
print('ln(x+1) ≈ ∑_{i=1}^'+str(i-1),'[(-1)^(i-1)][(x^i/i)] =',ln_x_plus_1)    
print("epsilon =","{:.0e}".format(epsilon))     
print('ln(x+1) = ',math.log(x+1))
# Out:
#          n   ∑_{i=1}^n  [(-1)^(i-1)][(x^i/i)]         |x^n/n|                epsilon
#          1    0.29999999999999999    0.29999999999999999    1e-06
#          2    0.25500000000000000    -0.04500000000000000    1e-06
#          3    0.26400000000000001    0.00900000000000000    1e-06
#          4    0.26197500000000001    -0.00202500000000000    1e-06
#          5    0.26246100000000000    0.00048600000000000    1e-06
#          6    0.26233950000000000    -0.00012150000000000    1e-06
#          7    0.26237074285714285    0.00003124285714286    1e-06
#          8    0.26236254160714284    -0.00000820125000000    1e-06
#          9    0.26236472860714283    0.00000218700000000    1e-06
#         10    0.26236413811714282    -0.00000059049000000    1e-06
# n =  10
# x =  0.3
# ln(x+1) ≈ ∑_{i=1}^10 [(-1)^(i-1)][(x^i/i)] = 0.2623641381171428
# epsilon = 1e-06
# ln(x+1) =  0.26236426446749106

# %%
# Returns Min n, |x^{n}/n!| < epsilon and ∑_{i=0}^{n} x^i/i!
import math

x = 0.8
epsilon = 10**(-6)

ln_x_plus_1 = 0

delta = 1
i = 0
print("n".rjust(10)," ","∑_{i=0}^n x^i/i!".center(20)," "," deltax^n/n!".center(20)," ","epsilon".center(9))
while  epsilon <= abs(delta):
  if i==0:
    pass
  else:
    delta = ((-1)**(i-1))*(x**i/(i))
    ln_x_plus_1 += delta
    print(format(i, '10'),"  ", format(ln_x_plus_1, '.17f'),"  ",format(delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1

print("n = ",i-1)
print('x = ',x)
print('ln(x+1) ≈ ∑_{i=1}^'+str(i-1),'[(-1)^(i-1)][(x^i/i)] =',ln_x_plus_1)    
print("epsilon =","{:.0e}".format(epsilon))     
print('ln(x+1) = ',math.log(x+1))
# Out:
#          n     ∑_{i=0}^n x^i/i!          deltax^n/n!        epsilon
#          1    0.80000000000000004    0.80000000000000004    1e-06
#          2    0.47999999999999998    -0.32000000000000006    1e-06
#          3    0.65066666666666673    0.17066666666666672    1e-06
#          4    0.54826666666666668    -0.10240000000000002    1e-06
#          5    0.61380266666666672    0.06553600000000001    1e-06
#          6    0.57011200000000006    -0.04369066666666668    1e-06
#          7    0.60007131428571436    0.02995931428571430    1e-06
#          8    0.57909979428571434    -0.02097152000000001    1e-06
#          9    0.59401287517460322    0.01491308088888890    1e-06
#         10    0.58327545693460325    -0.01073741824000001    1e-06
#         11    0.59108448838187599    0.00780903144727273    1e-06
#         12    0.58535786532054268    -0.00572662306133334    1e-06
#         13    0.58958675619660417    0.00422889087606154    1e-06
#         14    0.58644529440295845    -0.00314146179364572    1e-06
#         15    0.58879091920888060    0.00234562480592214    1e-06
#         16    0.58703170060443899    -0.00175921860444160    1e-06
#         17    0.58835628873013623    0.00132458812569721    1e-06
#         18    0.58735548881294275    -0.00100079991719344    1e-06
#         19    0.58811398980281571    0.00075850098987293    1e-06
#         20    0.58753752905051226    -0.00057646075230342    1e-06
#         21    0.58797673724274346    0.00043920819223118    1e-06
#         22    0.58764134189594874    -0.00033539534679472    1e-06
#         23    0.58789799224827866    0.00025665035232987    1e-06
#         24    0.58770122697815907    -0.00019676527011957    1e-06
#         25    0.58785234270561093    0.00015111572745183    1e-06
#         26    0.58773609983834030    -0.00011624286727064    1e-06
#         27    0.58782564989905250    0.00008955006071219    1e-06
#         28    0.58775656842364599    -0.00006908147540655    1e-06
#         29    0.58780992790809794    0.00005335948445196    1e-06
#         30    0.58776866324012178    -0.00004126466797618    1e-06
#         31    0.58780061007984530    0.00003194683972349    1e-06
#         32    0.58777585127905962    -0.00002475880078571    1e-06
#         33    0.58779505810633581    0.00001920682727619    1e-06
#         34    0.58778014456986249    -0.00001491353647327    1e-06
#         35    0.58779173451820743    0.00001158994834494    1e-06
#         36    0.58778272011393917    -0.00000901440426829    1e-06
#         37    0.58778973673131552    0.00000701661737640    1e-06
#         38    0.58778427115567500    -0.00000546557564056    1e-06
#         39    0.58778853150181531    0.00000426034614034    1e-06
#         40    0.58778520843182580    -0.00000332306998946    1e-06
#         41    0.58778780204742731    0.00000259361560153    1e-06
#         42    0.58778577655714803    -0.00000202549027929    1e-06
#         43    0.58778735926583137    0.00000158270868335    1e-06
#         44    0.58778612187540624    -0.00000123739042517    1e-06
#         45    0.58778708978969441    0.00000096791428813    1e-06
# n =  45
# x =  0.8
# ln(x+1) ≈ ∑_{i=1}^45 [(-1)^(i-1)][(x^i/i)] = 0.5877870897896944
# epsilon = 1e-06
# ln(x+1) =  0.5877866649021191

# %%
import math

x = 0.38

epsilon = 10**(-6)
ln_x_plus_1= 0

delta = 1
i = 1
print("n".rjust(10)," ","∑_{i=1}^n  [(-1)^(i-1)][(x^i/i)]".center(21)," ","|x^n/n|".center(20)," ","epsilon".center(20))
while  epsilon <= abs(delta):
  delta = ((-1)**(i-1))*(x**i/(i))
  ln_x_plus_1 += delta
  print(format(i, '10'),"  ", format(ln_x_plus_1, '.17f'),"  ",format(delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1

print("n = ",i-1) 
print('x = ',x)
print('ln_x_plus_1 ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',ln_x_plus_1)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.log(x+1) = ',math.log(x+1))
# Out:
#          n   ∑_{i=1}^n  [(-1)^(i-1)][(x^i/i)]         |x^n/n|                epsilon
#          1    0.38000000000000000    0.38000000000000000    1e-06
#          2    0.30780000000000002    -0.07220000000000000    1e-06
#          3    0.32609066666666670    0.01829066666666667    1e-06
#          4    0.32087782666666670    -0.00521284000000000    1e-06
#          5    0.32246253002666669    0.00158470336000000    1e-06
#          6    0.32196070729600001    -0.00050182273066667    1e-06
#          7    0.32212415812827427    0.00016345083227429    1e-06
#          8    0.32206981072654306    -0.00005434740173120    1e-06
#          9    0.32208816807112783    0.00001835734458476    1e-06
#         10    0.32208188985927982    -0.00000627821184799    1e-06
#         11    0.32208405869610002    0.00000216883682021    1e-06
#         12    0.32208330321794099    -0.00000075547815904    1e-06
# n =  12
# x =  0.38
# ln_x_plus_1 ≈ ∑_{i=0}^12 x^i/i! = 0.322083303217941
# epsilon = 1e-06
# math.log(x+1) =  0.3220834991691132

# %% [markdown]
# # For  $x$ negative  and less than  $-9$ at the middle phase of the algorithm there are problems caused by rounding errors due to differences that produce wrong answers.
#
# https://stackoverflow.com/questions/69978341/error-of-taylor-series-ex-for-negative-x

# %%
import math

x = -0.003
epsilon = 10**(-6)
ln_x_plus_1= 0

delta = 1
i = 1
print("n".rjust(10)," ","∑_{i=1}^n  x^i/i!".center(21)," ","error=ln(x+1) x^(n+1)/(n+1)!".center(20)," ","epsilon".center(20))
while  epsilon <= abs(delta):
  delta = ((-1)**(i-1))*(x**i/(i))
  ln_x_plus_1 += delta
  print(format(i, '10'),"  ", format(ln_x_plus_1, '.17f'),"  ",format(delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1

print("n = ",i-1) 
print('x = ',x)
print('ln(x+1) ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',ln_x_plus_1)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.log(x+1) = ',math.log(x+1))
# Out:
#          n     ∑_{i=1}^n  x^i/i!     error=ln(x+1) x^(n+1)/(n+1)!         epsilon
#          1    -0.00300000000000000    -0.00300000000000000    1e-06
#          2    -0.00300450000000000    -0.00000450000000000    1e-06
#          3    -0.00300450900000000    -0.00000000900000000    1e-06
# n =  3
# x =  -0.003
# ln(x+1) ≈ ∑_{i=0}^3 x^i/i! = -0.0030045090000000003
# epsilon = 1e-06
# math.log(x+1) =  -0.0030045090202987243

# %%
import math

x = 0.7
epsilon = 10**(-6)

delta = 1
ln_x_plus_1 = 0
i = 1

print("n".rjust(10)," ","∑_{i=1}^n  x^i/i!".center(21)," ","error=ln(x+1) x^(n+1)/(n+1)!".center(20)," ","epsilon".center(20))
while  epsilon <= abs(delta):
  delta = ((-1)**(i-1))*(x**i/(i))
  ln_x_plus_1 += delta
  print(format(i, '10'),"  ", format(ln_x_plus_1, '.17f'),"  ",format(delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1
  
print("n = ",i-1) 
print('x = ',x)
print('ln_x_plus_1 ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',ln_x_plus_1)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.log(x+1) = ',math.log(x+1))
# Out:
#          n     ∑_{i=1}^n  x^i/i!     error=ln(x+1) x^(n+1)/(n+1)!         epsilon
#          1    0.69999999999999996    0.69999999999999996    1e-06
#          2    0.45499999999999996    -0.24499999999999997    1e-06
#          3    0.56933333333333325    0.11433333333333330    1e-06
#          4    0.50930833333333325    -0.06002499999999999    1e-06
#          5    0.54292233333333328    0.03361399999999999    1e-06
#          6    0.52331416666666664    -0.01960816666666666    1e-06
#          7    0.53507906666666660    0.01176489999999999    1e-06
#          8    0.52787306541666656    -0.00720600125000000    1e-06
#          9    0.53235679952777770    0.00448373411111111    1e-06
#         10    0.52953204703777768    -0.00282475249000000    1e-06
#         11    0.53132961680414126    0.00179756976636364    1e-06
#         12    0.53017617620405788    -0.00115344060008333    1e-06
#         13    0.53092147628411168    0.00074530008005385    1e-06
#         14    0.53043703123207664    -0.00048444505203500    1e-06
#         15    0.53075353533273950    0.00031650410066287    1e-06
#         16    0.53054582951667950    -0.00020770581606001    1e-06
#         17    0.53068267099549549    0.00013684147881600    1e-06
#         18    0.53059220357338932    -0.00009046742210614    1e-06
#         19    0.53065219775857553    0.00005999418518617    1e-06
#         20    0.53061230162542672    -0.00003989613314881    1e-06
#         21    0.53063889904752592    0.00002659742209920    1e-06
#         22    0.53062112713366871    -0.00001777191385720    1e-06
#         23    0.53063302658903400    0.00001189945536525    1e-06
#         24    0.53062504403772648    -0.00000798255130752    1e-06
#         25    0.53063040831220509    0.00000536427447866    1e-06
#         26    0.53062679774284449    -0.00000361056936063    1e-06
#         27    0.53062923153404318    0.00000243379119865    1e-06
#         28    0.53062758872498406    -0.00000164280905909    1e-06
#         29    0.53062869903731369    0.00000111031232959    1e-06
#         30    0.53062794772597066    -0.00000075131134302    1e-06
# n =  30
# x =  0.7
# ln_x_plus_1 ≈ ∑_{i=0}^30 x^i/i! = 0.5306279477259707
# epsilon = 1e-06
# math.log(x+1) =  0.5306282510621704

# %%
import math

x = -0.35
epsilon = 10**(-5)

delta = 1
ln_x_plus_one = 0
i = 1

print("n".rjust(10)," ","∑_{i=1}^n  x^i/i!".center(21)," ","error=ln(x+1) x^(n+1)/(n+1)!".center(20)," ","epsilon".center(20))
while  epsilon <= abs(delta):
  delta = ((-1)**(i-1))*(x**i/(i))
  ln_x_plus_one+= delta
  print(format(i, '10'),"  ", format(ln_x_plus_one, '.17f'),"  ",format( delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1
  
print("n = ",i-1) 
print('x = ',x)
print('ln_plus_1 ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',ln_x_plus_one)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.log(x+1) = ',math.log(x+1))
# Out:
#          n     ∑_{i=1}^n  x^i/i!     error=ln(x+1) x^(n+1)/(n+1)!         epsilon
#          1    -0.34999999999999998    -0.34999999999999998    1e-05
#          2    -0.41124999999999995    -0.06124999999999999    1e-05
#          3    -0.42554166666666660    -0.01429166666666666    1e-05
#          4    -0.42929322916666657    -0.00375156250000000    1e-05
#          5    -0.43034366666666657    -0.00105043750000000    1e-05
#          6    -0.43065004427083325    -0.00030637760416667    1e-05
#          7    -0.43074195755208328    -0.00009191328125000    1e-05
#          8    -0.43077010599446608    -0.00002814844238281    1e-05
#          9    -0.43077886328765186    -0.00000875729318576    1e-05
# n =  9
# x =  -0.35
# ln_plus_1 ≈ ∑_{i=0}^9 x^i/i! = -0.43077886328765186
# epsilon = 1e-05
# math.log(x+1) =  -0.4307829160924542

# %%
import math

x = -0.99
epsilon = 10**(-5)

delta = 1
ln_x_plus_one = 0
i = 1

print("n".rjust(10)," ","∑_{i=1}^n  x^i/i!".center(21)," ","error=ln(x+1) x^(n+1)/(n+1)!".center(20)," ","epsilon".center(20))
while  epsilon <= abs(delta):
  delta = ((-1)**(i-1))*(x**i/(i))
  ln_x_plus_one+= delta
  print(format(i, '10'),"  ", format(ln_x_plus_one, '.17f'),"  ",format( delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1
  
print("n = ",i-1) 
print('x = ',x)
print('ln_plus_1 ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',ln_x_plus_one)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.log(x+1) = ',math.log(x+1))
# Out:
#          n     ∑_{i=1}^n  x^i/i!     error=ln(x+1) x^(n+1)/(n+1)!         epsilon
#          1    -0.98999999999999999    -0.98999999999999999    1e-05
#          2    -1.48004999999999987    -0.49004999999999999    1e-05
#          3    -1.80348299999999995    -0.32343300000000003    1e-05
#          4    -2.04363200249999988    -0.24014900249999999    1e-05
#          5    -2.23383001247999990    -0.19019800997999997    1e-05
#          6    -2.39074337071349996    -0.15691335823350000    1e-05
#          7    -2.52389556327164133    -0.13315219255814142    1e-05
#          8    -2.63923865007513125    -0.11534308680349001    1e-05
#          9    -2.74074056646220265    -0.10150191638707121    1e-05
#        125    4727839468229345280.00000000000000000    0.00000810552388023    1e-05
# n =  125
# x =  -43
# e_to_x ≈ ∑_{i=0}^125 x^i/i! = 2.115131037591081e-19
# epsilon = 1e-05
# math.exp(x) =  2.1151310375910805e-19

# %% [markdown]
# # Efficeincy
# Efficient
#
# https://stackoverflow.com/questions/69978341/error-of-taylor-series-ex-for-negative-x
#
# $$
# \begin{array}{lll}
# e^{ x}  & \approx   &\sum_{i=0}^{n} \frac{x^i}{i!}  \\
#         & = & 1 + x + \frac{x^2}{2!} + \frac{x^3}{3!} +\cdots+ \frac{x^n}{n!}  \\
#        & = &1 + \left[ 1  * \frac{x}{1} \right]  + \left[  \left( 1 *  \frac{x}{1} \right)  \frac{x}{2} \right]+ \left[ \left( 1 *  \frac{x}{1} \frac{x}{2} \right) * \frac{x}{3} \right]+ \left[  \left(1 *  \frac{x}{1} \frac{x}{2}   \frac{x}{3}\right) * \frac{x}{4}\right]  +\cdots+ \left[  \left(1 *  \frac{x}{1}  \frac{x}{2} \cdots  \frac{x}{n-1} \right)* \frac{x}{n} \right] \ \ \text{ efficient}
# \end{array}
# $$
#
#
#
# Additions
# $$ n \text{ additions } $$
#
# Multiplications
# $$ n \text{ multiplications } $$
#
# Divisions
# $$ n \text{ divsions }$$
#
# TOTAL
# $$ 3n = \Theta(n) \text{ FLOPS }$$

# %%
# Returns Min n, |x^{n}/n!| < epsilon and ∑_{i=0}^{n} x^i/i!

import time

start = time.time()

x = 700
epsilon = 10**(-20)

xo = x

if x < 0 :
   x = - x


delta = 1
e_to_x = 1
i = 1

while  epsilon <= abs(delta):
  delta *= x/i 
  e_to_x += delta
  i = i+1

if x != xo: 
  e_to_x = 1 / e_to_x
  x = xo

end = time.time()

print("n = ",i-1) 
print('x = ',x)
print('e_to_x ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',e_to_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.exp(x) = ',math.exp(x))
print('time = ',end - start)
# Out:
# n =  1944
# x =  700
# e_to_x ≈ ∑_{i=0}^1944 x^i/i! = 1.0142320547350058e+304
# epsilon = 1e-20
# math.exp(x) =  1.0142320547350045e+304
# time =  0.0012767314910888672

# %%
# Returns Min n, |x^{n}/n!| < epsilon and ∑_{i=0}^{n} x^i/i!

import time

start = time.time()

x = -700
epsilon = 10**(-20)

neg = False
if x < 0 :
  x = abs(x)
  neg = True

delta = 1
e_to_x = 1
i = 1

while  epsilon <= abs(delta):
  delta *= x/i 
  e_to_x += delta
  i = i+1

if x != xo: 
  e_to_x = 1 / e_to_x
  x = xo

end = time.time()

print("n = ",i-1) 
print('x = ',x)
print('e_to_x ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',e_to_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.exp(x) = ',math.exp(x))
print('time = ',end - start)
# Out:
# n =  1944
# x =  700
# e_to_x ≈ ∑_{i=0}^1944 x^i/i! = 1.0142320547350058e+304
# epsilon = 1e-20
# math.exp(x) =  1.0142320547350045e+304
# time =  0.0014717578887939453

# %% [markdown]
# Inefficient
#
# $$ e^{ x} \approx \sum_{i=0}^{n} \frac{x^i}{i!} =\sum_{i=0}^{n} \frac{x**i}{math.factorial(i)}$$
#
# Additions
# $$ n \text{ additions } $$
#
# Multiplications
#
# * Powers - exponentiation by squaring
# $$ x^i = x**i$$
#
# <center>
# <a href="https://en.wikipedia.org/wiki/Exponentiation_by_squaring">https://en.wikipedia.org/wiki/Exponentiation_by_squaring</a>
# </center>
# $$\lg i \text{ multiplications }$$
# <center>
# <a href="https://math.stackexchange.com/questions/228744/value-of-summation-of-logn">https://math.stackexchange.com/questions/228744/value-of-summation-of-logn</a>
# </center>
# $$ \sum_{i=1}^{n}\lg i \approx  n \lg n$$
#
#
# * Factorials
# $$math.factorial(i), $$
# $$  i-1 \text{ mutiplications }  $$
# $$ \sum_{i=1}^{n} i-1 = \frac{n(n-1)}{2} =  \frac{1}{2} n^2 - \frac{1}{2} n\text{ mutiplications}$$
#
# Divisions
# $$ n-1 \text{ divsions }$$
#
# TOTAL
# $$ \frac{1}{2} n^2 + n \lg n + \frac{3}{2} n -1 = \Theta(n^2) \text{ FLOPS }$$

# %%
import math
import time

start = time.time()

x = 700
epsilon = 10**(-20)

xo = x

if x < 0 :
   x = - x

delta = 1
e_to_x = 0
i = 0
while  epsilon <= abs(delta):
  delta = x**i/math.factorial(i) 
  e_to_x += delta
  i = i+1

if x != xo: 
  e_to_x = 1 / e_to_x
  x = xo

end = time.time()

print("n = ",i-1) 
print('x = ',x)
print('e_to_x ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',e_to_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.exp(x) = ',math.exp(x))
print('time = ',end - start)
# Out:
# n =  1944
# x =  700
# e_to_x ≈ ∑_{i=0}^1944 x^i/i! = 1.0142320547350051e+304
# epsilon = 1e-20
# math.exp(x) =  1.0142320547350045e+304
# time =  0.15405535697937012

# %% [markdown]
# Inefficient
#
# $$ e^{ x} \approx \sum_{i=0}^{n} \frac{x^i}{i!} =  \sum_{i=1}^{n} \frac{\overset{i\ times}{x*x*\cdots*x}}{1*2*\cdots*i}$$
#
# > Indented block
#
#
#
# Additions
# $$ n \text{ additions } $$
#
# Multiplications
#
# * Powers
# $$ \overset{i\ times}{x*x*\cdots*x}$$
# $$i-1 \text{ multiplications }$$
# $$ \sum_{i=1}^{n}\ i-1 = \frac{n(n-1)}{2} = \frac{1}{2} n^2 - \frac{1}{2} n\text{ mutiplications}$$
#
# * Factorials
# $$1*2*\cdots*i$$
# $$  i-1 \text{ mutiplications }  $$
# $$ \sum_{i=1}^{n} i-1 = \frac{n(n-1)}{2} = \frac{1}{2} n^2 - \frac{1}{2} n\text{ mutiplications}$$
#
# Divisions
# $$ n-1 \text{ divsions }$$
#
# TOTAL
# $$ n^2  + n -1  = \Theta(n^2) \text{ FLOPS }$$

# %%
import time

start = time.time()

x = 700
epsilon = 10**(-20)

xo = x

if x < 0 :
   x = - x

delta = 1
e_to_x = 1
i = 1
while  epsilon <= abs(delta):
  
  x_to_i = 1
  fact_of_i = 1
  for k in range(1,i+1):
      x_to_i *= x
      fact_of_i *= k

  delta = x_to_i/fact_of_i 
  e_to_x += delta
  i = i+1

if x != xo: 
  e_to_x = 1 / e_to_x
  x = xo

end = time.time()

print("n = ",i-1) 
print('x = ',x)
print('e_to_x ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',e_to_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.exp(x) = ',math.exp(x))
print('time = ',end - start)
# Out:
# n =  1944
# x =  700
# e_to_x ≈ ∑_{i=0}^1944 x^i/i! = 1.0142320547350051e+304
# epsilon = 1e-20
# math.exp(x) =  1.0142320547350045e+304
# time =  3.1211209297180176

# %% [markdown]
# # Error using the Lagrange's formula of the Residual $E_n$
#
# * Form: Numerical Analysis Mathematics of Scientific Computing David Kincaid and Ward Cheney and Error estimates in Taylor approximations https://math.dartmouth.edu/~m8s17/ErrorEstimates.pdf
#
# ## Lagrange's formula of the Residual
# For the Taylor series for $f(x)$
#
# $$ E_n = \frac{f^{(n+1)}(\xi)}{(n+1)!}(x-c)^{(n+1)} \text{ for }  \xi \text{ between } c \text{ and } x $$
#
# If you can find a positive real number $M$such that
# $$\left|f^{(n+1)}(\xi)\right|  \le M \text{ for }  \xi \text{ between } c \text{ and } x $$ for all
#  then Lagrange’s formula tells you
# that
# $$ \left| E_n \right| \le  \frac{M}{(n+1)!}
# \left|x − c\right|^{(n+1)} $$
#
# For the Taylor series for $f(x) = e^x$ about $c=0$ (Maclaurin)
#
# * If $x \ge 0$ then $f(n+1)(ξ)= e^ξ < e^x$ for any $0 \le \xi \le x$ then
#
# $$ \left|E_n \right| =  \left|\frac{f^{(n+1)}(\xi)}{(n+1)!}(x-c)^{(n+1)} \right| = \left|\frac{e^\xi}{(n+1)!}x^{(n+1)} \right| \le \left| \frac{e^x}{(n+1)!}x^{(n+1)} \right| $$

# %% [markdown]
# <center>
# <img src = "https://raw.githubusercontent.com/gjhernandezp/NM/main/Taylor%20Series/e_to_epsilon.png" alt = "e_to_minus_epsilon.png]">  </img>
# </center>

# %% [markdown]
# * If $x \le 0$ then $f(n+1)(ξ)= e^ξ < e^0  = 1$ for any $x \le \xi < 0$ then
#
# $$ \left|E_n =\right| = \left|\frac{f^{(n+1)}(\xi)}{(n+1)!}(x-c)^{(n+1)} \right| = \left|\frac{e^\xi}{(n+1)!}x^{(n+1)} \right| \le  \left|\frac{1}{(n+1)!}x^{(n+1)}\right| $$

# %% [markdown]
# <center>
# <img src = "https://raw.githubusercontent.com/gjhernandezp/NM/main/Taylor%20Series/e_to_minus_epsilon.png" alt = "e_to_minus_epsilon.png]">  </img>
# </center>

# %% [markdown]
# # What is the minimun $n$ for which the error using absolute value of the Lagrange's formula of the Residual $|E_n|$, of the Taylor series for $e^x$ about $0$ (Maclaurin  series), is less than  $\epsilon$.
#
# $$ \min_{n \in \mathbb{N}}|E_n|  < \epsilon $$
#
# this is
#
# $$\min_{n \in \mathbb{N}}\left\{ \left|\frac{e^x}{(n+1)!}x^{(n+1)} \right| \right\} < \epsilon \text{ if }  x \ge 0$$
#
# and
#
# $$\min_{n \in \mathbb{N}}\left\{  \left|\frac{1}{(n+1)!}x^{(n+1)} \right| \right\} < \epsilon \text{ if }  x < 0$$

# %%
# Returns Min n, |Lagrange_Residual_n| < epsilon and ∑_{i=0}^{n} x^i/i!

import math

x = 4
epsilon = 10**(-5)

e_to_x = 0

print("n".rjust(10)," ","∑_{i=0}^n x^i/i!".center(21)," ","|Lagrange_Residual_n|".center(20)," ","epsilon".center(20))
error = 1
i = 0
while  epsilon <= abs(error):
  e_to_x +=  x**i/math.factorial(i)
  if ( x >= 0 ):
     error = math.exp(x) * x**(i+1)/ math.factorial(i+1) 
  else:
     error = x**(i+1)/ math.factorial(i+1)
  print(format(i, '10'),"  ", format(e_to_x, '.17f'),"  ",format(error, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1
  
print("n = ",i-1) 
print('x = ',x)
print('e_to_x ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',e_to_x)
print("epsilon =","{:.0e}".format(epsilon))   
print('math.exp(x) = ',math.exp(x))
# Out:
#          n      ∑_{i=0}^n x^i/i!     |Lagrange_Residual_n|         epsilon
#          0    1.00000000000000000    218.39260013257694482    1e-05
#          1    5.00000000000000000    436.78520026515388963    1e-05
#          2    13.00000000000000000    582.38026702020522407    1e-05
#          3    23.66666666666666430    582.38026702020522407    1e-05
#          4    34.33333333333332860    465.90421361616415652    1e-05
#          5    42.86666666666666003    310.60280907744277101    1e-05
#          6    48.55555555555555003    177.48731947282442434    1e-05
#          7    51.80634920634920348    88.74365973641221217    1e-05
#          8    53.43174603174603021    39.44162654951654190    1e-05
#          9    54.15414462081128733    15.77665061980661676    1e-05
#         10    54.44310405643739159    5.73696386174786088    1e-05
#         11    54.54818021484688018    1.91232128724928696    1e-05
#         12    54.58320560098337637    0.58840654992285746    1e-05
#         13    54.59398264287153069    0.16811615712081643    1e-05
#         14    54.59706179769671763    0.04483097523221771    1e-05
#         15    54.59788290565010271    0.01120774380805443    1e-05
#         16    54.59808818263844898    0.00263711619013045    1e-05
#         17    54.59813648310629475    0.00058602582002899    1e-05
#         18    54.59814721654359460    0.00012337385684821    1e-05
#         19    54.59814947621460846    0.00002467477136964    1e-05
#         20    54.59814992814881407    0.00000469995645136    1e-05
# n =  20
# x =  4
# e_to_x ≈ ∑_{i=0}^20 x^i/i! = 54.598149928148814
# epsilon = 1e-05
# math.exp(x) =  54.598150033144236

# %%
# Returns Min n, |Lagrange Residual| < epsilon and ∑_{i=0}^{n} x^i/i!

import math

x  = -4
epsilon = 10**(-5)

e_to_x = 0

print("n".rjust(10)," ","∑_{i=0}^n x^i/i!".center(21)," ","|Lagrange_Residual_n|".center(20)," ","epsilon".center(20))
error = 1
i = 0
while  epsilon <= abs(error):
  e_to_x +=  x**i/math.factorial(i)
  if ( x >= 0 ):
     error = math.exp(x) * x**(i+1)/ math.factorial(i+1) 
  else:
     error = x**(i+1)/ math.factorial(i+1)
  print(format(i, '10'),"  ", format(e_to_x, '.17f'),"  ",format(error, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1
  
print("n = ",i-1) 
print('x = ',x)
print('e_to_x ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',e_to_x)
print("epsilon =","{:.0e}".format(epsilon))   
print('math.exp(x) = ',math.exp(x))
# Out:
#          n      ∑_{i=0}^n x^i/i!     |Lagrange_Residual_n|         epsilon
#          0    1.00000000000000000    -4.00000000000000000    1e-05
#          1    -3.00000000000000000    8.00000000000000000    1e-05
#          2    5.00000000000000000    -10.66666666666666607    1e-05
#          3    -5.66666666666666607    10.66666666666666607    1e-05
#          4    5.00000000000000000    -8.53333333333333321    1e-05
#          5    -3.53333333333333321    5.68888888888888911    1e-05
#          6    2.15555555555555589    -3.25079365079365079    1e-05
#          7    -1.09523809523809490    1.62539682539682540    1e-05
#          8    0.53015873015873050    -0.72239858906525578    1e-05
#          9    -0.19223985890652528    0.28895943562610227    1e-05
#         10    0.09671957671957698    -0.10507615840949175    1e-05
#         11    -0.00835658168991477    0.03502538613649725    1e-05
#         12    0.02666880444658248    -0.01077704188815300    1e-05
#         13    0.01589176255842949    0.00307915482518657    1e-05
#         14    0.01897091738361606    -0.00082110795338309    1e-05
#         15    0.01814980943023297    0.00020527698834577    1e-05
#         16    0.01835508641857874    -0.00004830046784606    1e-05
#         17    0.01830678595073268    0.00001073343729913    1e-05
#         18    0.01831751938803181    -0.00000225967101034    1e-05
# n =  18
# x =  -4
# e_to_x ≈ ∑_{i=0}^18 x^i/i! = 0.018317519388031805
# epsilon = 1e-05
# math.exp(x) =  0.01831563888873418

# %% [markdown]
# #  Sympy
#
# Taylor Series Expansion with Python from Data Science Fabric
#
# https://dsfabric.org/taylor-series-expansion-with-python

# %%
from sympy import series, Symbol, pi, E, N
from sympy.functions import exp
from sympy.plotting import plot
import matplotlib.pyplot as plt

# %%
# Define symbol
x = Symbol('x')

# %%
# Function for Taylor Series Expansion

def taylor(function, x0, n):
    """
    Parameter "function" is our function which we want to approximate
    "x0" is the point where to approximate
    "n" is the order of approximation
    """
    return function.series(x,x0,n)

# %%
print('e(x)  ≅')
taylor(exp(x), 0, 8)
# Out:
# e(x)  ≅
# 1 + x + x**2/2 + x**3/6 + x**4/24 + x**5/120 + x**6/720 + x**7/5040 + O(x**8)

# %%
print('e(x) ≅', taylor(exp(x), 0, 8))
# Out:
# e(x) ≅ 1 + x + x**2/2 + x**3/6 + x**4/24 + x**5/120 + x**6/720 + x**7/5040 + O(x**8)

# %%
print('e(x) ≅ at around 1')
taylor(exp(x), 1, 8)
# Out:
# e(x) ≅ at around 1
# E + E*(x - 1) + E*(x - 1)**2/2 + E*(x - 1)**3/6 + E*(x - 1)**4/24 + E*(x - 1)**5/120 + E*(x - 1)**6/720 + E*(x - 1)**7/5040 + O((x - 1)**8, (x, 1))

# %%
print('e(1) =', taylor(exp(x), 0, 4).subs(x,1))
# Out:
# e(1) = O(1)

# %%
print('e(1) =', N(taylor(exp(x), 0, 4).subs(x,1)))
# Out:
# e(1) = O(1)

# %%
print('Taylor 0 exp(x) ≅', taylor(exp(x), 0, 0))
print('Taylor 1 exp(x) ≅', taylor(exp(x), 0, 1))
print('Taylor 2 exp(x) ≅', taylor(exp(x), 0, 2))
print('Taylor 3 exp(x) ≅', taylor(exp(x), 0, 3))
print('Taylor 4 exp(x) ≅', taylor(exp(x), 0, 4))
print('Taylor 5 exp(x) ≅', taylor(exp(x), 0, 5))
print('Taylor 6 exp(x) ≅', taylor(exp(x), 0, 6))
print('Taylor 7 exp(x) ≅', taylor(exp(x), 0, 7))
print('Taylor 8 exp(x) ≅', taylor(exp(x), 0, 8))
# Out:
# Taylor 0 exp(x) ≅ O(1)
# Taylor 1 exp(x) ≅ 1 + O(x)
# Taylor 2 exp(x) ≅ 1 + x + O(x**2)
# Taylor 3 exp(x) ≅ 1 + x + x**2/2 + O(x**3)
# Taylor 4 exp(x) ≅ 1 + x + x**2/2 + x**3/6 + O(x**4)
# Taylor 5 exp(x) ≅ 1 + x + x**2/2 + x**3/6 + x**4/24 + O(x**5)
# Taylor 6 exp(x) ≅ 1 + x + x**2/2 + x**3/6 + x**4/24 + x**5/120 + O(x**6)
# Taylor 7 exp(x) ≅ 1 + x + x**2/2 + x**3/6 + x**4/24 + x**5/120 + x**6/720 + O(x**7)
# Taylor 8 exp(x) ≅ 1 + x + x**2/2 + x**3/6 + x**4/24 + x**5/120 + x**6/720 + x**7/5040 + O(x**8)

# %%
print('Taylor 0 exp(x) ≅', taylor(exp(x), 0, 0).subs(x,1))
print('Taylor 1 exp(x) ≅', taylor(exp(x), 0, 1).subs(x,1))
print('Taylor 2 exp(x) ≅', taylor(exp(x), 0, 2).subs(x,1))
print('Taylor 3 exp(x) ≅', taylor(exp(x), 0, 3).subs(x,1))
print('Taylor 4 exp(x) ≅', taylor(exp(x), 0, 4).subs(x,1))
print('Taylor 5 exp(x) ≅', taylor(exp(x), 0, 5).subs(x,1))
print('Taylor 6 exp(x) ≅', taylor(exp(x), 0, 6).subs(x,1))
print('Taylor 7 exp(x) ≅', taylor(exp(x), 0, 7).subs(x,1))
print('Taylor 8 exp(x) ≅', taylor(exp(x), 0, 8).subs(x,1))
# Out:
# Taylor 0 exp(x) ≅ O(1)
# Taylor 1 exp(x) ≅ O(1)
# Taylor 2 exp(x) ≅ O(1)
# Taylor 3 exp(x) ≅ O(1)
# Taylor 4 exp(x) ≅ O(1)
# Taylor 5 exp(x) ≅ O(1)
# Taylor 6 exp(x) ≅ O(1)
# Taylor 7 exp(x) ≅ O(1)
# Taylor 8 exp(x) ≅ O(1)

# %%
print('Taylor 0 exp(x) ≅', N(taylor(exp(x), 0, 0).subs(x,1)))
print('Taylor 1 exp(x) ≅', N(taylor(exp(x), 0, 1).subs(x,1)))
print('Taylor 2 exp(x) ≅', N(taylor(exp(x), 0, 2).subs(x,1)))
print('Taylor 3 exp(x) ≅', N(taylor(exp(x), 0, 3).subs(x,1)))
print('Taylor 4 exp(x) ≅', N(taylor(exp(x), 0, 4).subs(x,1)))
print('Taylor 5 exp(x) ≅', N(taylor(exp(x), 0, 5).subs(x,1)))
print('Taylor 6 exp(x) ≅', N(taylor(exp(x), 0, 6).subs(x,1)))
print('Taylor 7 exp(x) ≅', N(taylor(exp(x), 0, 7).subs(x,1)))
print('Taylor 8 exp(x) ≅', N(taylor(exp(x), 0, 8).subs(x,1)))
# Out:
# Taylor 0 exp(x) ≅ O(1)
# Taylor 1 exp(x) ≅ O(1)
# Taylor 2 exp(x) ≅ O(1)
# Taylor 3 exp(x) ≅ O(1)
# Taylor 4 exp(x) ≅ O(1)
# Taylor 5 exp(x) ≅ O(1)
# Taylor 6 exp(x) ≅ O(1)
# Taylor 7 exp(x) ≅ O(1)
# Taylor 8 exp(x) ≅ O(1)

# %%
# Function for Taylor Series Expansion

def taylor(function, x0, n):
    """
    Parameter "function" is our function which we want to approximate
    "x0" is the point where to approximate
    "n" is the order of approximation
    """
    return function.series(x,x0,n).removeO()

# %%
print('e(x)  ≅')
taylor(exp(x), 0, 8)
# Out:
# e(x)  ≅
# x**7/5040 + x**6/720 + x**5/120 + x**4/24 + x**3/6 + x**2/2 + x + 1

# %%
print('e(x) ≅', taylor(exp(x), 0, 8))
# Out:
# e(x) ≅ x**7/5040 + x**6/720 + x**5/120 + x**4/24 + x**3/6 + x**2/2 + x + 1

# %%
print('e(x) ≅ at around 1')
taylor(exp(x), 1, 8)
# Out:
# e(x) ≅ at around 1
# E*(x - 1)**7/5040 + E*(x - 1)**6/720 + E*(x - 1)**5/120 + E*(x - 1)**4/24 + E*(x - 1)**3/6 + E*(x - 1)**2/2 + E*(x - 1) + E

# %%
print('e(1) =', taylor(exp(x), 0, 4).subs(x,1))
# Out:
# e(1) = 8/3

# %%
print('e(1) =', N(taylor(exp(x), 0, 4).subs(x,1)))
# Out:
# e(1) = 2.66666666666667

# %%
print('Taylor 0 exp(x) ≅', taylor(exp(x), 0, 0))
print('Taylor 1 exp(x) ≅', taylor(exp(x), 0, 1))
print('Taylor 2 exp(x) ≅', taylor(exp(x), 0, 2))
print('Taylor 3 exp(x) ≅', taylor(exp(x), 0, 3))
print('Taylor 4 exp(x) ≅', taylor(exp(x), 0, 4))
print('Taylor 5 exp(x) ≅', taylor(exp(x), 0, 5))
print('Taylor 6 exp(x) ≅', taylor(exp(x), 0, 6))
print('Taylor 7 exp(x) ≅', taylor(exp(x), 0, 7))
print('Taylor 8 exp(x) ≅', taylor(exp(x), 0, 8))
# Out:
# Taylor 0 exp(x) ≅ 0
# Taylor 1 exp(x) ≅ 1
# Taylor 2 exp(x) ≅ x + 1
# Taylor 3 exp(x) ≅ x**2/2 + x + 1
# Taylor 4 exp(x) ≅ x**3/6 + x**2/2 + x + 1
# Taylor 5 exp(x) ≅ x**4/24 + x**3/6 + x**2/2 + x + 1
# Taylor 6 exp(x) ≅ x**5/120 + x**4/24 + x**3/6 + x**2/2 + x + 1
# Taylor 7 exp(x) ≅ x**6/720 + x**5/120 + x**4/24 + x**3/6 + x**2/2 + x + 1
# Taylor 8 exp(x) ≅ x**7/5040 + x**6/720 + x**5/120 + x**4/24 + x**3/6 + x**2/2 + x + 1

# %%
print('Taylor 0 exp(x) ≅', taylor(exp(x), 0, 0).subs(x,1))
print('Taylor 1 exp(x) ≅', taylor(exp(x), 0, 1).subs(x,1))
print('Taylor 2 exp(x) ≅', taylor(exp(x), 0, 2).subs(x,1))
print('Taylor 3 exp(x) ≅', taylor(exp(x), 0, 3).subs(x,1))
print('Taylor 4 exp(x) ≅', taylor(exp(x), 0, 4).subs(x,1))
print('Taylor 5 exp(x) ≅', taylor(exp(x), 0, 5).subs(x,1))
print('Taylor 6 exp(x) ≅', taylor(exp(x), 0, 6).subs(x,1))
print('Taylor 7 exp(x) ≅', taylor(exp(x), 0, 7).subs(x,1))
print('Taylor 8 exp(x) ≅', taylor(exp(x), 0, 8).subs(x,1))
# Out:
# Taylor 0 exp(x) ≅ 0
# Taylor 1 exp(x) ≅ 1
# Taylor 2 exp(x) ≅ 2
# Taylor 3 exp(x) ≅ 5/2
# Taylor 4 exp(x) ≅ 8/3
# Taylor 5 exp(x) ≅ 65/24
# Taylor 6 exp(x) ≅ 163/60
# Taylor 7 exp(x) ≅ 1957/720
# Taylor 8 exp(x) ≅ 685/252

# %%
print('Taylor 0 exp(x) ≅', N(taylor(exp(x), 0, 0).subs(x,1)))
print('Taylor 1 exp(x) ≅', N(taylor(exp(x), 0, 1).subs(x,1)))
print('Taylor 2 exp(x) ≅', N(taylor(exp(x), 0, 2).subs(x,1)))
print('Taylor 3 exp(x) ≅', N(taylor(exp(x), 0, 3).subs(x,1)))
print('Taylor 4 exp(x) ≅', N(taylor(exp(x), 0, 4).subs(x,1)))
print('Taylor 5 exp(x) ≅', N(taylor(exp(x), 0, 5).subs(x,1)))
print('Taylor 6 exp(x) ≅', N(taylor(exp(x), 0, 6).subs(x,1)))
print('Taylor 7 exp(x) ≅', N(taylor(exp(x), 0, 7).subs(x,1)))
print('Taylor 8 exp(x) ≅', N(taylor(exp(x), 0, 8).subs(x,1)))
# Out:
# Taylor 0 exp(x) ≅ 0
# Taylor 1 exp(x) ≅ 1.00000000000000
# Taylor 2 exp(x) ≅ 2.00000000000000
# Taylor 3 exp(x) ≅ 2.50000000000000
# Taylor 4 exp(x) ≅ 2.66666666666667
# Taylor 5 exp(x) ≅ 2.70833333333333
# Taylor 6 exp(x) ≅ 2.71666666666667
# Taylor 7 exp(x) ≅ 2.71805555555556
# Taylor 8 exp(x) ≅ 2.71825396825397

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

values = np.arange(-5,5,0.1)
p_exp = np.exp(values)
t_exp1 = [taylor(exp(x), 0, 1).subs(x,v) for v in values]
legends = ['exp() ','Taylor 0 (constant)']

fig, ax = plt.subplots()
ax.plot(values,p_exp, color ='red')
ax.plot(values,t_exp1)

ax.set_ylim([-5,5])
ax.axhline(y=0.0, xmin=-5.0, xmax=5.0, color='black')
ax.axvline(x=0.0, ymin=-10.0, ymax=10.0, color='black')
ax.legend(legends)

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

values = np.arange(-5,5,0.1)
p_exp = np.exp(values)
t_exp2 = [taylor(exp(x), 0, 2).subs(x,v) for v in values]
legends = ['exp() ','Taylor 1 (linear)']

fig, ax = plt.subplots()
ax.plot(values,p_exp, color ='red')
ax.plot(values,t_exp2)

ax.set_ylim([-5,5])
ax.axhline(y=0.0, xmin=-5.0, xmax=5.0, color='black')
ax.axvline(x=0.0, ymin=-10.0, ymax=10.0, color='black')
ax.legend(legends)

plt.show()

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

values = np.arange(-5,5,0.1)
p_exp = np.exp(values)
t_exp3 = [taylor(exp(x), 0, 3).subs(x,v) for v in values]
legends = ['exp() ','Taylor 2 (quadratic)']

fig, ax = plt.subplots()
ax.plot(values,p_exp, color ='red')
ax.plot(values,t_exp3)

ax.set_ylim([-5,5])
ax.axhline(y=0.0, xmin=-5.0, xmax=5.0, color='black')
ax.axvline(x=0.0, ymin=-10.0, ymax=10.0, color='black')
ax.legend(legends)

plt.show()

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

values = np.arange(-5,5,0.1)
p_exp = np.exp(values)
t_exp4 = [taylor(exp(x), 0, 4).subs(x,v) for v in values]
legends = ['exp() ','Taylor 3 (cubic)']

fig, ax = plt.subplots()
ax.plot(values,p_exp, color ='red')
ax.plot(values,t_exp4)

ax.set_ylim([-5,5])
ax.axhline(y=0.0, xmin=-5.0, xmax=5.0, color='black')
ax.axvline(x=0.0, ymin=-10.0, ymax=10.0, color='black')
ax.legend(legends)

plt.show()

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

values = np.arange(-5,5,0.1)
p_exp = np.exp(values)
t_exp1 = [taylor(exp(x), 0, 1).subs(x,v) for v in values]
t_exp2 = [taylor(exp(x), 0, 2).subs(x,v) for v in values]
t_exp3 = [taylor(exp(x), 0, 3).subs(x,v) for v in values]
t_exp4 = [taylor(exp(x), 0, 4).subs(x,v) for v in values]
legends = ['exp() ','Taylor 0 (constant)','Taylor 1 (linear)','Taylor 2 (quadratic)','Taylor 3 (cubic)']

fig, ax = plt.subplots()
ax.plot(values,p_exp)
ax.plot(values,t_exp1)
ax.plot(values,t_exp2)
ax.plot(values,t_exp3)
ax.plot(values,t_exp4)

ax.set_ylim([-5,5])
ax.axhline(y=0.0, xmin=-5.0, xmax=5.0, color='black')
ax.axvline(x=0.0, ymin=-10.0, ymax=10.0, color='black')
ax.legend(legends)

plt.show()
