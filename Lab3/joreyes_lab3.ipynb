# %% [markdown]
# <a href="https://colab.research.google.com/github/joshuareyesc/MetNumUN2023I/blob/main/Lab3/joreyes_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LINK A LINKEDLN**
# https://www.linkedin.com/in/joshua-felipe-reyes-castillo-82165a267/

# %% [markdown]
# **CERTIFICADOS**

# %% [markdown]
# ![joreyescognitiveclassaapplieddatadciencewithpython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![joreyescognitiveclassaapplieddataanalysiswithpython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![joreyescognitiveclassaapplieddatavisualizationwithpython.jpg](data:image/jpeg;base64,...)
